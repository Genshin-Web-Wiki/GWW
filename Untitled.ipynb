# %%
import pandas as pd

# %%
data = pd.read_csv('genshinstats.csv')

# %%
data
# Out:
#     Character    Lv  Rarity Element   Weapon Main role        Ascension  \
# 0       Amber   1.0     4.0    Pyro      Bow   Sub DPS              ATK
# 1       Amber  20.0     4.0    Pyro      Bow   Sub DPS              ATK
# 2       Amber  20.0     4.0    Pyro      Bow   Sub DPS              ATK
# 3       Amber  40.0     4.0    Pyro      Bow   Sub DPS              ATK
# 4       Amber  40.0     4.0    Pyro      Bow   Sub DPS              ATK
# ..        ...   ...     ...     ...      ...       ...              ...
# 762   Yun Jin  60.0     4.0     Geo  Polearm   Support  Energy Recharge
# 763   Yun Jin  70.0     4.0     Geo  Polearm   Support  Energy Recharge
# 764   Yun Jin  80.0     4.0     Geo  Polearm   Support  Energy Recharge
# 765   Yun Jin  90.0     4.0     Geo  Polearm   Support  Energy Recharge
# 766       NaN   NaN     NaN     NaN      NaN       NaN              NaN
#
#      Base HP  Base ATK  Base DEF
# 0      793.0      19.0      50.0
# 1     2038.0      48.0     129.0
# ...

# %%
data.sample(15)
# Out:
#         Character    Lv  Rarity  Element    Weapon Main role        Ascension  \
# 756         Yelan  80.0     5.0    Hydro       Bow   Support        CRIT Rate
# 625        Collei  50.0     4.0   Dendro       Bow   Support              ATK
# 100          Jean  20.0     5.0    Anemo     Sword    Healer    Healing Bonus
# 457          Eula  70.0     5.0     Cryo  Claymore       DPS         CRIT DMG
# 56       Chongyun   1.0     4.0     Cryo  Claymore   Sub DPS              ATK
# 406         Ayaka   1.0     5.0     Cryo     Sword       DPS         CRIT DMG
# 527        Shogun  70.0     5.0  Electro   Polearm   Sub DPS  Energy Recharge
# 182     Ningguang   1.0     4.0      Geo  Catalyst       DPS          Geo DMG
# 505      Traveler  20.0     5.0      All     Sword   Support              ATK
# 329       Zhongli  60.0     5.0      Geo   Polearm   Support          Geo DMG
# 516      Traveler  80.0     5.0      All     Sword   Support              ATK
# ...

# %%
data[data.Character == 'Mika']
# Out:
# Empty DataFrame
# Columns: [Character, Lv, Rarity, Element, Weapon, Main role, Ascension, Base HP, Base ATK, Base DEF]
# Index: []

# %%
characters_lv90 = data[data.Lv == 90]
characters_lv90
# Out:
#     Character    Lv  Rarity  Element    Weapon Main role        Ascension  \
# 13      Amber  90.0     4.0     Pyro       Bow   Sub DPS              ATK
# 27    Barbara  90.0     4.0    Hydro  Catalyst    Healer               HP
# 41     Beidou  90.0     4.0  Electro  Claymore   Sub DPS      Electro DMG
# 55    Bennett  90.0     4.0     Pyro     Sword    Healer  Energy Recharge
# 69   Chongyun  90.0     4.0     Cryo  Claymore   Sub DPS              ATK
# ..        ...   ...     ...      ...       ...       ...              ...
# 733     Thoma  90.0     4.0     Pyro   Polearm   Support              ATK
# 741  Wanderer  90.0     5.0    Anemo  Catalyst       DPS        CRIT Rate
# 749  Yae Miko  90.0     5.0  Electro  Catalyst       DPS        CRIT Rate
# 757     Yelan  90.0     5.0    Hydro       Bow   Support        CRIT Rate
# 765   Yun Jin  90.0     4.0      Geo   Polearm   Support  Energy Recharge
#
#      Base HP  Base ATK  Base DEF
# 13    9461.0     223.0     601.0
# ...

# %%
characters_lv90.to_csv('characters_lv90.csv')
